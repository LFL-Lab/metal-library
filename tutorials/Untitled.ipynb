# %%
import pandas as pd
df = pd.read_csv("/Users/clarkmiyamoto/LFL_QubitLibraries/metal-library/metal_library/library/TransmonCross/QubitOnly.csv")

# %%
df
# Out:
#      Unnamed: 0  pos_x  pos_y   orientation  chip   layer  \
# 0             0      0  0.0um             0  main       1
# 1             1      0  0.0um             0  main       1
# 2             2      0  0.0um             0  main       1
# 3             3      0  0.0um             0  main       1
# 4             4      0  0.0um             0  main       1
# ..          ...    ...    ...           ...   ...     ...
# 723         723      0  0.0um             0  main       1
# 724         724      0  0.0um             0  main       1
# 725         725      0  0.0um             0  main       1
# 726         726      0  0.0um             0  main       1
# 727         727      0  0.0um             0  main       1
#
#       connection_pads.readout.connector_type  \
# 0                                          0
# 1                                          0
# 2                                          0
# 3                                          0
# ...
